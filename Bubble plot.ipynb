# %% [markdown]
# # Bubble Plot

# %%
# !pip install gapminder
# Out:
# Requirement already satisfied: gapminder in c:\users\ekuet\anaconda3\lib\site-packages (0.1)
# Requirement already satisfied: pandas in c:\users\ekuet\anaconda3\lib\site-packages (from gapminder) (1.3.4)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\ekuet\anaconda3\lib\site-packages (from pandas->gapminder) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ekuet\anaconda3\lib\site-packages (from pandas->gapminder) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\ekuet\anaconda3\lib\site-packages (from pandas->gapminder) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\ekuet\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->gapminder) (1.16.0)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\ekuet\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from gapminder import gapminder # data set

# data
data = gapminder.loc[gapminder.year == 2007]

# use the scatterplot function to build the bubble map
sns.scatterplot(data=data, x="gdpPercap", y="lifeExp", size="pop", legend=False, sizes=(20, 2000))

# show the graph
plt.show()
